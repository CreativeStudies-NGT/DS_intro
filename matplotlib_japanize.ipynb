# %%
# 日本語表示のためのライブラリをインストール
# !pip install japanize-matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import japanize_matplotlib  # 日本語表示用ライブラリ

plt.scatter([1, 2, 3], [4, 6, 9])
plt.title('簡単なグラフ', fontsize=16)
plt.xlabel('x軸', fontsize=14)
plt.ylabel('y軸', fontsize=14);
